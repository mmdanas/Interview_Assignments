# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
retention = pd.read_csv('overall_retention.csv')
engagement = pd.read_csv('overall_engagement.csv')
economy = pd.read_csv('overall_economy.csv')

# %%
retention.head()
# Out:
#    cli  d1(%)  d14(%)  d2(%)  d21(%)  d3(%)  d30(%)  d4(%)  d5(%)  d6(%)  \
# 0    0     60       0     45       0     32       0     30     27     24
# 1    0     59      17     45       0     32       0     33     28     23
# 2    0     66      18     50      18     40       0     34     34     30
# 3    0     59      18     45       0     35       0     31     30     28
# 4    0     61       0     48       0     36       0     33     27     27
#
#    d7(%)  date_field experiment  gid  installs  variant_group  version
# 0     24  09/04/2015    content    4       399              1        2
# 1     23  09/01/2015    content    4       767              3        2
# 2     27  08/25/2015    content    4       578              2        2
# 3     26  08/31/2015    content    4      1147              3        2
# 4     21  09/09/2015    content    4       418              3        2

# %%
engagement.head()
# Out:
#   action_type  actions  actions_per_dau  actions_per_user  cli  date_field  \
# 0        view    74708         9.068706          9.351358    0  09/16/2015
# 1    use_hint    13831         1.678927          2.504255    0  09/16/2015
# 2        fail    55098         6.668038          8.494912    0  09/05/2015
# 3       clear    76096         9.209246         13.234087    0  09/05/2015
# 4    use_hint    16879         1.895665          2.672419    0  09/13/2015
#
#     dau experiment  gid  users  variant_group  version
# 0  8238    content    4   7989              3        2
# 1  8238    content    4   5523              3        2
# 2  8263    content    4   6486              3        2
# 3  8263    content    4   5750              3        2
# 4  8904    content    4   6316              3        2

# %%
economy.head()
# Out:
#    cash_per_dau  cash_per_user  cli  date_field   dau earn_type experiment  \
# 0     49.216679      52.369801    0  2015-09-16  8238      earn    content
# 1     10.378733     814.285714    0  2015-09-16  8238  purchase    content
# 2      9.100811     844.943820    0  2015-09-05  8263  purchase    content
# 3    -69.799104     -98.270574    0  2015-09-05  8263     spend    content
# 4      9.456424     979.069767    0  2015-09-13  8904  purchase    content
#
#    gid  total_cash  users  variant_group  version
# 0    4      405447   7742              3        2
# 1    4       85500    105              3        2
# 2    4       75200     89              3        2
# 3    4     -576750   5869              3        2
# 4    4       84200     86              3        2

# %%
retention = retention[['cli','d1(%)','d2(%)','d3(%)','d4(%)','d5(%)','d6(%)','d7(%)','d14(%)','d21(%)','d30(%)','date_field','installs','variant_group','experiment','gid','version']]

# %%
retention.head()
# Out:
#    cli  d1(%)  d2(%)  d3(%)  d4(%)  d5(%)  d6(%)  d7(%)  d14(%)  d21(%)  \
# 0    0     60     45     32     30     27     24     24       0       0
# 1    0     59     45     32     33     28     23     23      17       0
# 2    0     66     50     40     34     34     30     27      18      18
# 3    0     59     45     35     31     30     28     26      18       0
# 4    0     61     48     36     33     27     27     21       0       0
#
#    d30(%)  date_field  installs  variant_group experiment  gid  version
# 0       0  09/04/2015       399              1    content    4        2
# 1       0  09/01/2015       767              3    content    4        2
# 2       0  08/25/2015       578              2    content    4        2
# 3       0  08/31/2015      1147              3    content    4        2
# 4       0  09/09/2015       418              3    content    4        2

# %%
plt.plot(retention.d1(%),retention.date_field)
plt.show()
# Out:
#   File "<ipython-input-16-e4ce40d2ce6e>", line 1
#     plt.plot(retention.d1(%),retention.date_field)
#                           ^
# SyntaxError: invalid syntax
